# %%
import matplotlib.pyplot as plt
import numpy as np

SMALL_SIZE =14
MEDIUM_SIZE = 24
BIGGER_SIZE = 28

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.style.use('seaborn')

# %% [markdown]
# # Qualitative comparison of complexity

# %%
karr = np.array([5,10, 20]) # max k is 20 -> 2^20 ~1e6 - in GP practice this is jitter term
r = 40
N = np.arange(2, 50)
n = 2.**N
s = np.round(10*np.log10(n))
o = []

fig = plt.figure(figsize = (12, 7))

ax = fig.add_subplot(1, 1, 1)


plt.fill_between(n, 0.05*n**3, 0.01* n*s**2, alpha = 0.25,hatch = 'x',edgecolor = 'C0',   label = 'Sparse GP')
plt.plot(n, 0.05*n**3, '--', c=  'C0')
plt.plot(n, 0.01*n*s**2, '--', c = 'C0')

#plt.plot(n, n**2, '--', label = 'BNN', c = 'darkgreen')
plt.fill_between(n, n**2, n, color = 'darkorange', alpha = 0.2, hatch = 'o', edgecolor = 'darkorange',  label = 'BNN')
plt.plot(n, n**2, '--', c = 'darkorange')
plt.plot(n, n, '--', c = 'darkorange')



karr = [40]
c = ['C0', 'C1', 'C3']
i = 2

r = 40
k = 25
#o.append(k*r*s * n * np.log(n) + 2**k + k**2)
ax.plot(n, k*r*s**2 * np.log(n) + 2**k + k**2, c ='red', label = 'QGP')

k = 5
ax.plot(n, k*r*s**2 * np.log(n) + 2**k + k**2,'--',  c ='red', label = 'Sparse QGP')

plt.plot(n, n**3, '-k', label = 'GP')

#plt.fill_between(n, k*r*s**2 * np.log(n) + 2**k + k**2, 
#                 k*r*n * np.log(n) + 2**k + k**2, alpha = 0.3, color ='darkred', label = 'QGP')

k0 = 10
k1 = 50

#i = i+1
    
#ax.axvspan(10**4, 10**8, alpha=0.1, color='red')

#ax.axhspan(10**12, 10**23, alpha=0.1, color='red')
#plt.xlim([2, 10**8])
plt.ylim( [1e4, 1e21])

#plt.text(5e1, 5e16, "Classically intractable", size=14, color='darkred')
plt.xlabel('System size n', fontsize = MEDIUM_SIZE)
plt.ylabel('Computing cost', fontsize = MEDIUM_SIZE)
ax.set_yscale('log')
ax.set_xscale('log')
plt.xticks(fontsize=MEDIUM_SIZE )
plt.yticks(fontsize=MEDIUM_SIZE )

plt.grid(True)
plt.legend(fontsize = MEDIUM_SIZE, loc = 2)
#plt.title('QGP scaling comparison', fontsize = MEDIUM_SIZE)
plt.show()
fig.savefig('Figures/2_scaling_comparison.pdf', inches = 'tight')
fig.savefig('Figures/2_scaling_comparison.eps', inches = 'tight', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Numerical verification of error bounds
# (Fig 3, 8, 9)

# %% [markdown]
# ## Series 1: Testing different Eigenspectra

# %% [markdown]
# ## Series 2: Testing approximations on benchmarking functions

# %% [markdown]
# # Cost-Accuracy trade-off
# Figure 4 and 10

# %% [markdown]
# # Cost model
# data, estimation of parameters table II

# %% [markdown]
# ## Extrapolated cost prediction

# %% [markdown]
# # Metamaterial Design

# %% [markdown]
# ## Dataset

# %% [markdown]
# ## Classification
# Fig 13 in SI

# %% [markdown]
# ## GP regression
# (Fig 6, Fig 14 in SI)

# %% [markdown]
# ### High fidelity classical GP model

# %% [markdown]
# ### Reduced classical GP model

# %% [markdown]
# ### QGP model

# %% [markdown]
# # Comparison of cut-off strategies
# Fig 7
